# %%
from faker import Faker
import random
import csv
fake = Faker()

TRAINING_DATA_SIZE = 50

fields = ["id",
    "name",
    "cgpa",
    "backend",
    "frontend",
    "database",
    "android",
    "ios",
    "cross_platform",
    "version_control_systems",
    "python",
    "multivariate_calculus_linear_algebra",
    "probability_statistics",
    "ml_algorithms",
    "communication_networks",
    "operating_system",
    "data_structures",
    "algorithms",
    "problem_solving_and_aptitude",
    "resume"
]

DATA_FILE_NAME = "data.csv"

RESUME_LINKS = [
    "https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view",
    "https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk",
    "https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1"
]

names = []
cgpa = []
backend = []
frontend = []
database = []
android = []
ios = []
cross_platform = []
version_control_systems = []
python = []
multivariate_calculus_linear_algebra = []
probability_statistics = []
ml_algorithms = []
communication_networks = []
operating_system = []
data_structures = []
algorithms = []
problem_solving_aptitude = []
resumes = []

for i in range(TRAINING_DATA_SIZE):
    names.append(fake.name())
    cgpa.append(random.uniform(5, 10))
    backend.append(random.randint(0, 10))
    frontend.append(random.randint(0, 10))
    database.append(random.randint(0, 10))
    android.append(random.randint(0, 10))
    ios.append(random.randint(0, 10))
    cross_platform.append(random.randint(0, 10))
    version_control_systems.append(random.randint(0, 10))
    python.append(random.randint(0, 10))
    multivariate_calculus_linear_algebra.append(random.randint(0, 10))
    probability_statistics.append(random.randint(0, 10))
    ml_algorithms.append(random.randint(0, 10))
    communication_networks.append(random.randint(0, 10))
    operating_system.append(random.randint(0, 10))
    data_structures.append(random.randint(0, 10))
    algorithms.append(random.randint(0, 10))
    problem_solving_aptitude.append(random.randint(0, 10))
    resumes.append(RESUME_LINKS[random.randint(0, RESUME_LINKS.__len__() - 1)])

dataset = []
for i in range(TRAINING_DATA_SIZE):
    temp = []
    temp.append(1001+i)
    temp.append(names[i])
    temp.append(cgpa[i])
    temp.append(backend[i])
    temp.append(frontend[i])
    temp.append(database[i])
    temp.append(android[i])
    temp.append(ios[i])
    temp.append(cross_platform[i])
    temp.append(version_control_systems[i])
    temp.append(python[i])
    temp.append(multivariate_calculus_linear_algebra[i])
    temp.append(probability_statistics[i])
    temp.append(ml_algorithms[i])
    temp.append(communication_networks[i])
    temp.append(operating_system[i])
    temp.append(data_structures[i])
    temp.append(algorithms[i])
    temp.append(problem_solving_aptitude[i])
    temp.append(resumes[i])
    dataset.append(temp)

with open(DATA_FILE_NAME, 'w', newline='') as csvFile:
    csvWriter = csv.writer(csvFile)
    csvWriter.writerow(fields)
    csvWriter.writerows(dataset)

# %%
import pandas as pd
import firebase_admin
from firebase_admin import credentials, firestore

cred = credentials.Certificate("../firebase.json")

firebase_admin.initialize_app(cred, {
    'databaseURL': 'https://devathon.firebaseio.com'
})

db = firestore.client()
doc_ref = db.collection(u'applications')

df = pd.read_csv('data.csv')
tmp = df.to_dict(orient='records')
list(map(lambda x: doc_ref.add(x), tmp))

docs = doc_ref.stream()
for doc in docs:
    print(f'{doc.id} => {doc.to_dict()}')
# Out:
# 1rcxIlRxOWqjxQ5bALRv => {'algorithms': 9, 'id': 1017, 'backend': 9, 'database': 5, 'data_structures': 6, 'cgpa': 8.360766771157575, 'android': 3, 'ios': 1, 'name': 'Gina Watts', 'ml_algorithms': 10, 'multivariate_calculus_linear_algebra': 7, 'python': 8, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 3, 'communication_networks': 5, 'probability_statistics': 2, 'problem_solving_and_aptitude': 3, 'operating_system': 2, 'cross_platform': 1, 'version_control_systems': 9}
# 28u9StfAkYz0mHRfLR1s => {'backend': 7, 'algorithms': 4, 'id': 1013, 'database': 0, 'data_structures': 6, 'cgpa': 8.210496019912366, 'android': 1, 'ml_algorithms': 2, 'name': 'Nathan Rice', 'ios': 4, 'multivariate_calculus_linear_algebra': 4, 'python': 6, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 0, 'communication_networks': 0, 'probability_statistics': 3, 'problem_solving_and_aptitude': 9, 'operating_system': 9, 'cross_platform': 6, 'version_control_systems': 5}
# 3R91dQVgLsTi9aXRGQCs => {'algorithms': 2, 'backend': 9, 'id': 1044, 'database': 7, 'data_structures': 4, 'cgpa': 8.62542015697942, 'android': 8, 'ml_algorithms': 6, 'name': 'Joshua White', 'ios': 2, 'multivariate_calculus_linear_algebra': 7, 'python': 9, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 2, 'communication_networks': 0, 'version_control_systems': 0, 'problem_solving_and_aptitude': 4, 'operating_system': 7, 'cross_platform': 3, 'probability_statistics': 6}
# 4CNDRexeSTRvD4jREIt6 => {'backend': 4, 'algorithms': 3, 'id': 1035, 'data_structures': 0, 'database': 9, 'cgpa': 6.135655412570992, 'android': 0, 'ios': 5, 'name': 'Suzanne Goodman DDS', 'ml_algorithms': 2, 'multivariate_calculus_linear_algebra': 4, 'python': 7, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 7, 'communication_networks': 3, 'probability_statistics': 8, 'problem_solving_and_aptitude': 4, 'operating_system': 8, 'cross_platform': 6, 'version_control_systems': 0}
# 6WO79g4xzprKAKSKX790 => {'algorithms': 5, 'backend': 7, 'id': 1032, 'database': 5, 'data_structures': 1, 'cgpa': 8.70464969767552, 'android': 2, 'ml_algorithms': 5, 'name': 'Erica Mendez', 'ios': 4, 'multivariate_calculus_linear_algebra': 10, 'python': 10, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 3, 'communication_networks': 2, 'version_control_systems': 6, 'problem_solving_and_aptitude': 1, 'operating_system': 1, 'cross_platform': 7, 'probability_statistics': 6}
# 75tKGkelUvBagENCsJ66 => {'id': 1014, 'algorithms': 3, 'backend': 7, 'data_structures': 9, 'database': 3, 'cgpa': 5.502270049717116, 'android': 4, 'ios': 0, 'name': 'Leslie Tran', 'ml_algorithms': 4, 'multivariate_calculus_linear_algebra': 10, 'python': 4, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 8, 'communication_networks': 4, 'version_control_systems': 10, 'problem_solving_and_aptitude': 8, 'operating_system': 0, 'cross_platform': 0, 'probability_statistics': 7}
# 78lpYsjnOuwmPUcqidFD => {'algorithms': 4, 'backend': 1, 'id': 1007, 'data_structures': 2, 'database': 10, 'cgpa': 9.779486744813576, 'android': 1, 'ml_algorithms': 8, 'name': 'Barbara Price', 'ios': 3, 'multivariate_calculus_linear_algebra': 8, 'python': 8, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 8, 'communication_networks': 5, 'version_control_systems': 4, 'problem_solving_and_aptitude': 3, 'operating_system': 1, 'cross_platform': 4, 'probability_statistics': 3}
# 7gIA3nYxXRk7tpP4Aw4F => {'backend': 10, 'id': 1012, 'algorithms': 5, 'data_structures': 3, 'database': 3, 'cgpa': 6.16751759896324, 'android': 8, 'ml_algorithms': 1, 'name': 'Tyler Webb', 'ios': 1, 'multivariate_calculus_linear_algebra': 9, 'python': 3, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 5, 'communication_networks': 5, 'version_control_systems': 0, 'problem_solving_and_aptitude': 3, 'operating_system': 6, 'cross_platform': 0, 'probability_statistics': 3}
# 7tGo1OIk7ScUziJ8m0Gp => {'algorithms': 1, 'id': 1037, 'backend': 8, 'data_structures': 6, 'database': 8, 'cgpa': 8.316832277216614, 'android': 2, 'ios': 2, 'name': 'Charles Wells', 'ml_algorithms': 7, 'multivariate_calculus_linear_algebra': 0, 'python': 4, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 10, 'communication_networks': 3, 'version_control_systems': 10, 'problem_solving_and_aptitude': 7, 'operating_system': 2, 'cross_platform': 0, 'probability_statistics': 4}
# 97KuzsFWQBwFSzLYyB7p => {'id': 1038, 'backend': 5, 'algorithms': 0, 'data_structures': 9, 'database': 2, 'cgpa': 8.357443075451053, 'android': 0, 'ios': 0, 'name': 'Sherry Rivera', 'ml_algorithms': 3, 'multivariate_calculus_linear_algebra': 6, 'python': 1, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 8, 'communication_networks': 6, 'version_control_systems': 2, 'problem_solving_and_aptitude': 8, 'operating_system': 5, 'cross_platform': 6, 'probability_statistics': 6}
# GVh5Y2x3pJpdZZx23yRV => {'algorithms': 9, 'backend': 5, 'id': 1046, 'database': 8, 'data_structures': 6, 'cgpa': 5.23654376985605, 'android': 8, 'ml_algorithms': 1, 'name': 'Cheyenne Fox', 'ios': 8, 'multivariate_calculus_linear_algebra': 8, 'python': 9, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 8, 'communication_networks': 6, 'probability_statistics': 6, 'problem_solving_and_aptitude': 0, 'operating_system': 6, 'cross_platform': 10, 'version_control_systems': 3}
# GeQOQVPqiCS1o39nDGtM => {'id': 1008, 'backend': 4, 'algorithms': 1, 'database': 2, 'data_structures': 8, 'cgpa': 7.136102422323525, 'android': 10, 'ios': 4, 'name': 'Carolyn Campos', 'ml_algorithms': 4, 'multivariate_calculus_linear_algebra': 0, 'python': 1, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 8, 'communication_networks': 6, 'version_control_systems': 0, 'problem_solving_and_aptitude': 1, 'operating_system': 3, 'cross_platform': 5, 'probability_statistics': 10}
# IUaUK8hGFJZvjFCJEmVh => {'algorithms': 7, 'id': 1025, 'backend': 9, 'data_structures': 4, 'database': 2, 'cgpa': 9.638569704645866, 'android': 5, 'ios': 1, 'name': 'Lisa Avila', 'ml_algorithms': 8, 'multivariate_calculus_linear_algebra': 10, 'python': 8, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 4, 'communication_networks': 2, 'version_control_systems': 7, 'problem_solving_and_aptitude': 4, 'operating_system': 8, 'cross_platform': 5, 'probability_statistics': 10}
# Ibjfwr7zLldYinTv8zqH => {'backend': 5, 'algorithms': 9, 'id': 1033, 'database': 3, 'data_structures': 4, 'cgpa': 6.4723701336422765, 'android': 10, 'ml_algorithms': 1, 'name': 'Richard Webb', 'ios': 6, 'multivariate_calculus_linear_algebra': 10, 'python': 9, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 2, 'communication_networks': 8, 'version_control_systems': 0, 'problem_solving_and_aptitude': 2, 'operating_system': 10, 'cross_platform': 1, 'probability_statistics': 6}
# Iel7sbq5TVePEncQ7tmf => {'id': 1040, 'algorithms': 4, 'backend': 0, 'data_structures': 3, 'database': 1, 'cgpa': 6.830644847525456, 'android': 9, 'ios': 10, 'name': 'Carol Curry', 'ml_algorithms': 2, 'multivariate_calculus_linear_algebra': 7, 'python': 4, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 5, 'communication_networks': 10, 'probability_statistics': 10, 'problem_solving_and_aptitude': 8, 'operating_system': 2, 'cross_platform': 10, 'version_control_systems': 1}
# J20W7rKBb6uVpcAhzVuJ => {'algorithms': 4, 'backend': 7, 'id': 1009, 'database': 10, 'data_structures': 5, 'cgpa': 9.201757266075347, 'android': 10, 'ios': 6, 'name': 'Jennifer Perez', 'ml_algorithms': 3, 'multivariate_calculus_linear_algebra': 9, 'python': 1, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 5, 'communication_networks': 1, 'probability_statistics': 10, 'problem_solving_and_aptitude': 6, 'operating_system': 0, 'cross_platform': 10, 'version_control_systems': 10}
# JjcTw1mPnpGvNRZCisOM => {'id': 1043, 'backend': 8, 'algorithms': 7, 'data_structures': 1, 'database': 4, 'cgpa': 9.83797536651316, 'android': 2, 'ios': 8, 'name': 'Mark Steele', 'ml_algorithms': 3, 'multivariate_calculus_linear_algebra': 0, 'python': 5, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 6, 'communication_networks': 7, 'probability_statistics': 4, 'problem_solving_and_aptitude': 3, 'operating_system': 2, 'cross_platform': 0, 'version_control_systems': 10}
# JvGVyzztPBNHFCohW65G => {'backend': 4, 'id': 1019, 'algorithms': 1, 'data_structures': 6, 'database': 7, 'cgpa': 9.044564230696034, 'android': 9, 'ios': 9, 'name': 'Victoria Sanchez', 'ml_algorithms': 10, 'multivariate_calculus_linear_algebra': 4, 'python': 8, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 9, 'communication_networks': 5, 'version_control_systems': 5, 'problem_solving_and_aptitude': 7, 'operating_system': 0, 'cross_platform': 9, 'probability_statistics': 0}
# KR6VZtptd8ScQiDKIQOU => {'algorithms': 7, 'id': 1050, 'backend': 4, 'data_structures': 7, 'database': 10, 'cgpa': 9.87176596368573, 'android': 5, 'ios': 2, 'name': 'Ashlee Hampton', 'ml_algorithms': 6, 'multivariate_calculus_linear_algebra': 4, 'python': 3, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 4, 'communication_networks': 2, 'version_control_systems': 5, 'problem_solving_and_aptitude': 4, 'operating_system': 5, 'cross_platform': 3, 'probability_statistics': 3}
# LzHAqNDX73tXMmMlZY4A => {'algorithms': 1, 'backend': 3, 'id': 1041, 'data_structures': 10, 'database': 0, 'cgpa': 6.353506627585055, 'android': 9, 'ios': 0, 'name': 'Craig Orr', 'ml_algorithms': 1, 'multivariate_calculus_linear_algebra': 4, 'python': 3, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 0, 'communication_networks': 9, 'version_control_systems': 6, 'problem_solving_and_aptitude': 6, 'operating_system': 9, 'cross_platform': 0, 'probability_statistics': 10}
# MrlY23jtjk24mosgP5Cl => {'algorithms': 3, 'id': 1004, 'backend': 6, 'database': 3, 'data_structures': 10, 'cgpa': 6.724033371748354, 'android': 8, 'ml_algorithms': 5, 'name': 'Gerald Hughes', 'ios': 1, 'multivariate_calculus_linear_algebra': 5, 'python': 1, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 3, 'communication_networks': 2, 'probability_statistics': 1, 'problem_solving_and_aptitude': 10, 'operating_system': 2, 'cross_platform': 9, 'version_control_systems': 6}
# Nn2tT37IKabrDAkwaedx => {'id': 1005, 'algorithms': 8, 'backend': 3, 'data_structures': 4, 'database': 10, 'cgpa': 7.230529975307792, 'android': 7, 'ios': 8, 'name': 'Justin Sweeney', 'ml_algorithms': 4, 'multivariate_calculus_linear_algebra': 5, 'python': 8, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 1, 'communication_networks': 1, 'probability_statistics': 8, 'problem_solving_and_aptitude': 10, 'operating_system': 6, 'cross_platform': 10, 'version_control_systems': 0}
# OgW8Js4GgXtjz1HJkTSa => {'id': 1011, 'algorithms': 5, 'backend': 4, 'data_structures': 10, 'database': 2, 'cgpa': 7.412132605567892, 'android': 5, 'ios': 1, 'name': 'Gabrielle Boone', 'ml_algorithms': 10, 'multivariate_calculus_linear_algebra': 10, 'python': 5, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 8, 'communication_networks': 2, 'version_control_systems': 6, 'problem_solving_and_aptitude': 8, 'operating_system': 1, 'cross_platform': 8, 'probability_statistics': 7}
# OslUx8m3bXBTllAjjEfP => {'backend': 1, 'id': 1029, 'algorithms': 8, 'data_structures': 9, 'database': 2, 'cgpa': 6.347114241623129, 'android': 2, 'ios': 2, 'name': 'Becky Green', 'ml_algorithms': 2, 'multivariate_calculus_linear_algebra': 8, 'python': 7, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 0, 'communication_networks': 4, 'probability_statistics': 8, 'problem_solving_and_aptitude': 7, 'operating_system': 2, 'cross_platform': 2, 'version_control_systems': 5}
# PStYV4eqpirpUlffMs8E => {'id': 1023, 'algorithms': 7, 'backend': 9, 'database': 10, 'data_structures': 0, 'cgpa': 6.250512171448392, 'android': 10, 'ml_algorithms': 0, 'name': 'Joseph Hays', 'ios': 7, 'multivariate_calculus_linear_algebra': 7, 'python': 2, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 1, 'communication_networks': 9, 'version_control_systems': 8, 'problem_solving_and_aptitude': 5, 'operating_system': 9, 'cross_platform': 10, 'probability_statistics': 8}
# Pxwos3JCf5mgS0oQQHyt => {'id': 1045, 'algorithms': 8, 'backend': 9, 'data_structures': 1, 'database': 10, 'cgpa': 5.413752599897201, 'android': 10, 'ios': 5, 'name': 'Jessica Jones', 'ml_algorithms': 0, 'multivariate_calculus_linear_algebra': 5, 'python': 0, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 10, 'communication_networks': 9, 'version_control_systems': 6, 'problem_solving_and_aptitude': 4, 'operating_system': 6, 'cross_platform': 3, 'probability_statistics': 3}
# REEEMZkaQYTR7RgKNUB0 => {'backend': 3, 'id': 1020, 'algorithms': 1, 'database': 0, 'data_structures': 10, 'cgpa': 8.625536396172151, 'android': 10, 'ml_algorithms': 5, 'name': 'Jesse Lara', 'ios': 1, 'multivariate_calculus_linear_algebra': 3, 'python': 5, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 10, 'communication_networks': 1, 'probability_statistics': 7, 'problem_solving_and_aptitude': 2, 'operating_system': 9, 'cross_platform': 9, 'version_control_systems': 8}
# SSCwcmYU1dLWB0EMZN99 => {'algorithms': 8, 'backend': 1, 'id': 1042, 'database': 1, 'data_structures': 3, 'cgpa': 5.923310011941235, 'android': 6, 'ios': 1, 'name': 'Lynn Bell', 'ml_algorithms': 0, 'multivariate_calculus_linear_algebra': 8, 'python': 4, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 0, 'communication_networks': 4, 'version_control_systems': 3, 'problem_solving_and_aptitude': 10, 'operating_system': 6, 'cross_platform': 1, 'probability_statistics': 3}
# Wj5yeHhi0jV4Kp9LdNmK => {'algorithms': 8, 'id': 1030, 'backend': 9, 'database': 7, 'data_structures': 2, 'cgpa': 9.541513926641912, 'android': 10, 'ml_algorithms': 6, 'name': 'Briana Thompson', 'ios': 0, 'multivariate_calculus_linear_algebra': 0, 'python': 6, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 8, 'communication_networks': 6, 'probability_statistics': 7, 'problem_solving_and_aptitude': 4, 'operating_system': 6, 'cross_platform': 7, 'version_control_systems': 5}
# Y4yNsFdD3UDsuyMIXzQn => {'id': 1016, 'algorithms': 4, 'backend': 8, 'data_structures': 6, 'database': 0, 'cgpa': 8.798511106117388, 'android': 2, 'ml_algorithms': 3, 'name': 'Dakota Roberson', 'ios': 0, 'multivariate_calculus_linear_algebra': 4, 'python': 8, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 2, 'communication_networks': 4, 'version_control_systems': 4, 'problem_solving_and_aptitude': 6, 'operating_system': 5, 'cross_platform': 8, 'probability_statistics': 8}
# b0abuwFKoQy0EbHRJrgJ => {'backend': 5, 'id': 1028, 'algorithms': 3, 'data_structures': 4, 'database': 8, 'cgpa': 5.120844784276468, 'android': 2, 'ml_algorithms': 2, 'name': 'Lisa Hart', 'ios': 5, 'multivariate_calculus_linear_algebra': 4, 'python': 7, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 7, 'communication_networks': 10, 'version_control_systems': 7, 'problem_solving_and_aptitude': 1, 'operating_system': 10, 'cross_platform': 6, 'probability_statistics': 5}
# d8rDXrXeBgJrqC4Gieze => {'algorithms': 10, 'id': 1031, 'backend': 10, 'database': 2, 'data_structures': 2, 'cgpa': 5.653533138892582, 'android': 3, 'ios': 0, 'name': 'William Williams', 'ml_algorithms': 1, 'multivariate_calculus_linear_algebra': 9, 'python': 5, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 2, 'communication_networks': 4, 'version_control_systems': 6, 'problem_solving_and_aptitude': 10, 'operating_system': 8, 'cross_platform': 7, 'probability_statistics': 9}
# d8ttYyabVB1Scl87iK3x => {'algorithms': 10, 'backend': 4, 'id': 1006, 'database': 7, 'data_structures': 7, 'cgpa': 9.681473268988192, 'android': 5, 'ios': 0, 'name': 'John Williams', 'ml_algorithms': 1, 'multivariate_calculus_linear_algebra': 4, 'python': 3, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 6, 'communication_networks': 7, 'probability_statistics': 10, 'problem_solving_and_aptitude': 4, 'operating_system': 1, 'cross_platform': 4, 'version_control_systems': 1}
# dZZazHG5bNKtLx82tHAx => {'backend': 0, 'algorithms': 6, 'id': 1018, 'database': 0, 'data_structures': 2, 'cgpa': 6.965990803932969, 'android': 5, 'ml_algorithms': 0, 'name': 'Chad Martinez', 'ios': 8, 'multivariate_calculus_linear_algebra': 2, 'python': 4, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 8, 'communication_networks': 3, 'probability_statistics': 4, 'problem_solving_and_aptitude': 5, 'operating_system': 9, 'cross_platform': 3, 'version_control_systems': 2}
# e59jW7IZ16peFQTLw4u3 => {'backend': 5, 'algorithms': 7, 'id': 1010, 'database': 5, 'data_structures': 4, 'cgpa': 7.702664713224338, 'android': 1, 'ios': 1, 'name': 'Brenda Elliott', 'ml_algorithms': 9, 'multivariate_calculus_linear_algebra': 10, 'python': 10, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 6, 'communication_networks': 2, 'probability_statistics': 7, 'problem_solving_and_aptitude': 9, 'operating_system': 4, 'cross_platform': 3, 'version_control_systems': 7}
# eQA6y9KfgNntOJ02qV54 => {'id': 1026, 'algorithms': 5, 'backend': 4, 'database': 7, 'data_structures': 2, 'cgpa': 5.945888273190532, 'android': 5, 'ios': 3, 'name': 'Shane Hernandez', 'ml_algorithms': 10, 'multivariate_calculus_linear_algebra': 9, 'python': 2, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 8, 'communication_networks': 7, 'probability_statistics': 1, 'problem_solving_and_aptitude': 5, 'operating_system': 0, 'cross_platform': 7, 'version_control_systems': 0}
# fcXrv73yQpu84aFiKA3T => {'backend': 10, 'id': 1003, 'algorithms': 4, 'data_structures': 6, 'database': 10, 'cgpa': 5.41218142256152, 'android': 7, 'ios': 1, 'name': 'Hannah Martin', 'ml_algorithms': 1, 'multivariate_calculus_linear_algebra': 2, 'python': 0, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 6, 'communication_networks': 7, 'version_control_systems': 5, 'problem_solving_and_aptitude': 8, 'operating_system': 1, 'cross_platform': 4, 'probability_statistics': 0}
# fgPthUCTnm3KiOqJYcSF => {'algorithms': 10, 'backend': 4, 'id': 1022, 'data_structures': 2, 'database': 6, 'cgpa': 6.236860798968422, 'android': 7, 'ml_algorithms': 0, 'name': 'Thomas Dixon', 'ios': 0, 'multivariate_calculus_linear_algebra': 4, 'python': 8, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 9, 'communication_networks': 6, 'version_control_systems': 10, 'problem_solving_and_aptitude': 8, 'operating_system': 8, 'cross_platform': 6, 'probability_statistics': 4}
# h9W4lpDayH256Odmbcmp => {'algorithms': 4, 'id': 1021, 'backend': 5, 'database': 7, 'data_structures': 8, 'cgpa': 9.067613641306298, 'android': 3, 'ios': 0, 'name': 'Heidi Schneider', 'ml_algorithms': 0, 'multivariate_calculus_linear_algebra': 5, 'python': 4, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 7, 'communication_networks': 3, 'version_control_systems': 2, 'problem_solving_and_aptitude': 1, 'operating_system': 9, 'cross_platform': 7, 'probability_statistics': 10}
# oZr0eUwSnYFkfWOFKhKo => {'algorithms': 10, 'id': 1015, 'backend': 2, 'data_structures': 4, 'database': 9, 'cgpa': 7.949509255016349, 'android': 9, 'ml_algorithms': 8, 'name': 'Cynthia Lee', 'ios': 6, 'multivariate_calculus_linear_algebra': 5, 'python': 3, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 6, 'communication_networks': 3, 'version_control_systems': 10, 'problem_solving_and_aptitude': 0, 'operating_system': 6, 'cross_platform': 3, 'probability_statistics': 10}
# p8enKwuqE2t38Dc2oHiZ => {'backend': 6, 'id': 1001, 'algorithms': 2, 'data_structures': 6, 'database': 2, 'cgpa': 5.119942058287818, 'android': 1, 'ml_algorithms': 0, 'name': 'Johnathan Jones', 'ios': 1, 'multivariate_calculus_linear_algebra': 1, 'python': 8, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 3, 'communication_networks': 3, 'version_control_systems': 10, 'problem_solving_and_aptitude': 1, 'operating_system': 9, 'cross_platform': 4, 'probability_statistics': 10}
# pn7yzBo8CgC6T8PccAVg => {'algorithms': 0, 'id': 1048, 'backend': 3, 'database': 3, 'data_structures': 3, 'cgpa': 5.354162108472593, 'android': 9, 'ml_algorithms': 10, 'name': 'Leah Gibbs', 'ios': 6, 'multivariate_calculus_linear_algebra': 5, 'python': 0, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 1, 'communication_networks': 0, 'probability_statistics': 8, 'problem_solving_and_aptitude': 4, 'operating_system': 2, 'cross_platform': 10, 'version_control_systems': 3}
# q9WSDbsDNcCrh0gMbP2D => {'algorithms': 0, 'backend': 7, 'id': 1027, 'data_structures': 4, 'database': 0, 'cgpa': 9.289584137382525, 'android': 7, 'ios': 10, 'name': 'Jesse Johnson', 'ml_algorithms': 4, 'multivariate_calculus_linear_algebra': 3, 'python': 4, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 3, 'communication_networks': 9, 'version_control_systems': 2, 'problem_solving_and_aptitude': 8, 'operating_system': 8, 'cross_platform': 10, 'probability_statistics': 10}
# q9emvxNfGWnH3YhZx2Hi => {'id': 1036, 'algorithms': 6, 'backend': 7, 'database': 4, 'data_structures': 10, 'cgpa': 6.343264570588117, 'android': 7, 'ml_algorithms': 5, 'name': 'Sonia Wilkerson DDS', 'ios': 10, 'multivariate_calculus_linear_algebra': 8, 'python': 4, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 5, 'communication_networks': 4, 'version_control_systems': 4, 'problem_solving_and_aptitude': 6, 'operating_system': 10, 'cross_platform': 6, 'probability_statistics': 7}
# sHbnJZtQr7utPikik2w4 => {'algorithms': 0, 'id': 1034, 'backend': 1, 'database': 2, 'data_structures': 3, 'cgpa': 5.110638449502925, 'android': 0, 'ml_algorithms': 8, 'name': 'Mary Key', 'ios': 7, 'multivariate_calculus_linear_algebra': 6, 'python': 10, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 8, 'communication_networks': 0, 'version_control_systems': 10, 'problem_solving_and_aptitude': 10, 'operating_system': 8, 'cross_platform': 8, 'probability_statistics': 0}
# tbvg2lmz9npw7SFiDmBQ => {'backend': 1, 'algorithms': 5, 'id': 1024, 'data_structures': 3, 'database': 7, 'cgpa': 7.405822984939553, 'android': 4, 'ml_algorithms': 5, 'name': 'Karen Dean', 'ios': 1, 'multivariate_calculus_linear_algebra': 7, 'python': 5, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 7, 'communication_networks': 7, 'version_control_systems': 0, 'problem_solving_and_aptitude': 5, 'operating_system': 9, 'cross_platform': 9, 'probability_statistics': 4}
# uCVb12vPRDmk9BoBA5oR => {'backend': 1, 'algorithms': 9, 'id': 1039, 'data_structures': 2, 'database': 10, 'cgpa': 9.959470870626658, 'android': 9, 'ml_algorithms': 6, 'name': 'Thomas Kent', 'ios': 6, 'multivariate_calculus_linear_algebra': 3, 'python': 2, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 0, 'communication_networks': 10, 'probability_statistics': 7, 'problem_solving_and_aptitude': 7, 'operating_system': 10, 'cross_platform': 0, 'version_control_systems': 9}
# xC1eZwRYNZRXt0Qs2j0c => {'id': 1047, 'algorithms': 3, 'backend': 0, 'data_structures': 6, 'database': 4, 'cgpa': 6.055220331459962, 'android': 7, 'ios': 3, 'name': 'Janice Simmons', 'ml_algorithms': 6, 'multivariate_calculus_linear_algebra': 5, 'python': 10, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 10, 'communication_networks': 0, 'version_control_systems': 4, 'problem_solving_and_aptitude': 9, 'operating_system': 4, 'cross_platform': 10, 'probability_statistics': 9}
# yl8IYbVU2aCrpKu36gWj => {'backend': 3, 'algorithms': 2, 'id': 1049, 'database': 0, 'data_structures': 5, 'cgpa': 7.539624195495955, 'android': 10, 'ios': 8, 'name': 'Michael Short', 'ml_algorithms': 7, 'multivariate_calculus_linear_algebra': 10, 'python': 5, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 5, 'communication_networks': 10, 'version_control_systems': 0, 'problem_solving_and_aptitude': 4, 'operating_system': 4, 'cross_platform': 8, 'probability_statistics': 6}
# ywSJKOJ1eTmb6VMtVusw => {'algorithms': 10, 'id': 1002, 'backend': 8, 'database': 3, 'data_structures': 5, 'cgpa': 5.528995750699037, 'android': 3, 'ml_algorithms': 1, 'name': 'Amber Jenkins', 'ios': 4, 'multivariate_calculus_linear_algebra': 2, 'python': 9, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 9, 'communication_networks': 2, 'probability_statistics': 8, 'problem_solving_and_aptitude': 0, 'operating_system': 8, 'cross_platform': 4, 'version_control_systems': 4}
